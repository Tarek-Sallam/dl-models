# %%
import numpy as np
from autodiff.Tensor import Tensor
from models.MLP import MLP, Linear, ReLU
import matplotlib.pyplot as plt

# %%
num = 100
x = 10*np.random.rand(num)
y = 10*np.random.rand(num)
features = np.array([x, y])
features = features.T
labels = [0 if y - x - 5*(np.random.rand(1) - 0.5) > 0 else 1 for x, y in zip(x, y)]
colors = ['red' if label == 0 else 'blue' for label in labels]
fig, ax = plt.subplots()
ax.scatter(x, y, c=colors)

# %%
features = Tensor(features)
labels = Tensor(labels)

# %%
model = MLP([
    Linear(2, 4),
    ReLU(),
    Linear(4, 4),
    ReLU,
    Linear(4, 2),
])

model.forward(features)
model(features)
# Out:
# (100, 2)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 8
#       1 model = MLP([
#       2     Linear(2, 4),
#       3     ReLU(),
#    (...)      6     Linear(4, 2),
#       7 ])
# ----> 8 model(features)
#
# File ~/Projects/dl-models/dl-models/models/MLP.py:37, in MLP.__call__(self, X)
#      35     self.forward(X)
#      36 except Exception as e:
# ---> 37     raise e
#
# File ~/Projects/dl-models/dl-models/models/MLP.py:35, in MLP.__call__(self, X)
#      33 def __call__(self, X: Tensor):
#      34     try:
# ---> 35         self.forward(X)
#      36     except Exception as e:
#      37         raise e
#
# File ~/Projects/dl-models/dl-models/models/MLP.py:49, in MLP.forward(self, X)
#      47     return layer_output
#      48 except Exception as e:
# ---> 49     raise e
#
# File ~/Projects/dl-models/dl-models/models/MLP.py:44, in MLP.forward(self, X)
#      42 for layer in self.layers:
#      43     print(layer_output.data.shape)
# ---> 44     layer_output = layer(layer_output)
#      45     print(f"In layer {i}")
#      46     i+=1
#
# File ~/Projects/dl-models/dl-models/models/MLP.py:74, in Linear.__call__(self, X)
#      72     self.forward(X)
#      73 except Exception as e:
# ---> 74     raise e
#
# File ~/Projects/dl-models/dl-models/models/MLP.py:72, in Linear.__call__(self, X)
#      70 def __call__(self, X: Tensor):
#      71     try:
# ---> 72         self.forward(X)
#      73     except Exception as e:
#      74         raise e
#
# File ~/Projects/dl-models/dl-models/models/MLP.py:86, in Linear.forward(self, X)
#      84     return (X @ self.weights) + self.bias
#      85 except Exception as e:
# ---> 86     raise e
#
# File ~/Projects/dl-models/dl-models/models/MLP.py:84, in Linear.forward(self, X)
#      82 def forward(self, X: Tensor):
#      83     try:
# ---> 84         return (X @ self.weights) + self.bias
#      85     except Exception as e:
#      86         raise e
#
# File ~/Projects/dl-models/dl-models/autodiff/Tensor.py:128, in Tensor.__matmul__(self, other)
#     125     return out
#     127 except Exception as e:
# --> 128     raise e
#
# File ~/Projects/dl-models/dl-models/autodiff/Tensor.py:113, in Tensor.__matmul__(self, other)
#     111 try:
#     112     other = self.convertToTensor(other)
# --> 113     result = self.data @ other.data
#     114     out = Tensor(result, store_grad=self.store_grad or other.store_grad)
#     115     out._prev = {self, other}
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 4 is different from 2)
